# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split

# %%
# loading the data

# %%
data = pd.read_csv('i2w_train.csv')
data
# Out:
#      Unnamed: 0  index  frame  id     col     row   width  height timestamp  \
# 0             0      0     30   1  528.82  437.54   61.59   18.19  19:36:29
# 1            12     12     56   1  496.35  436.47   68.39   19.36  19:36:30
# 2            24     24    106   1  446.03  434.02   68.61   23.94  19:36:32
# 3            36     36    130   7  436.44  426.19   54.26   33.39  19:36:33
# 4            46     46    150   7  434.04  421.33   47.44   38.94  19:36:34
# ..          ...    ...    ...  ..     ...     ...     ...     ...       ...
# 210        2415   2415   3454  52  830.98  558.45  392.95  125.74  20:05:03
# 211        2428   2428   3480  52  745.04  545.49  456.10  156.79  20:05:04
# 212        2441   2441   3506  52  708.12  552.91  403.59  150.34  20:05:05
# 213        2454   2454   3532  52  666.20  555.14  366.09  145.83  20:05:06
# 214        2465   2465   3554  52  649.53  547.37  315.33  123.88  20:05:07
#
# ...

# %%
data.corr()
# Out:
#             Unnamed: 0     index     frame        id       col       row  \
# Unnamed: 0    1.000000  1.000000  0.306136 -0.052455  0.211757  0.536021
# index         1.000000  1.000000  0.306136 -0.052455  0.211757  0.536021
# frame         0.306136  0.306136  1.000000  0.615763  0.308624  0.492635
# id           -0.052455 -0.052455  0.615763  1.000000  0.444552  0.014383
# col           0.211757  0.211757  0.308624  0.444552  1.000000  0.402523
# row           0.536021  0.536021  0.492635  0.014383  0.402523  1.000000
# width         0.357371  0.357371  0.481186 -0.005977  0.178622  0.902021
# height        0.321430  0.321430  0.444860  0.014793  0.094563  0.803085
# ID            0.903185  0.903185 -0.031587 -0.211222  0.183994  0.448060
# lat          -0.019138 -0.019138 -0.441988 -0.564827 -0.905761 -0.389188
# lon          -0.022380 -0.022380 -0.352010  0.044435 -0.094541 -0.565229
# tcol          0.247340  0.247340  0.355897  0.431789  0.993504  0.495919
# ...

# %%
# tcol -> lat, trow -> long
from sklearn.preprocessing import MinMaxScaler

print(data[['trow', 'tcol', 'lon']])

data = MinMaxScaler().fit_transform(data[['trow', 'tcol', 'lon']])
print(data)
x, y = data[:, [0, 1]], data[:,-1]
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.30)
# Out:
#            plon         lon
# 0   -117.233711 -117.233807
# 1   -117.233720 -117.233839
# 2   -117.233769 -117.233903
# 3   -117.233805 -117.233924
# 4   -117.233821 -117.233956
# ..          ...         ...
# 210 -117.234444 -117.234505
# 211 -117.234454 -117.234502
# 212 -117.234457 -117.234499
# 213 -117.234457 -117.234497
# 214 -117.234438 -117.234491
#
# [215 rows x 2 columns]
# [[4.90600800e-01 5.90626747e-01 4.27300985e-01]
#  [5.08772263e-01 5.83757608e-01 4.07827032e-01]
#  [5.30409902e-01 5.44845533e-01 3.68794734e-01]
#  [5.31417969e-01 5.16414423e-01 3.55783560e-01]
#  [5.30489134e-01 5.03568063e-01 3.36088780e-01]
#  [5.38235478e-01 5.13170592e-01 3.19608347e-01]
#  [5.39322591e-01 5.26425464e-01 3.10934333e-01]
#  [5.10874399e-01 4.75580800e-01 2.99352212e-01]
#  [4.94847992e-01 4.60146574e-01 2.96137762e-01]
#  [4.57916280e-01 4.54314945e-01 2.92430226e-01]
#  [4.13945164e-01 4.32090342e-01 2.91647941e-01]
#  [3.70902193e-01 4.37073064e-01 2.95576611e-01]
# ...

# %%
# creating a model
model = keras.Sequential(
    [
        keras.layers.Dense(10, input_shape=[2], activation="relu"),
        keras.layers.Dense(10, activation="relu"),
        keras.layers.Dense(1, name="output")
        
    ]
)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                110
# _________________________________________________________________
# output (Dense)               (None, 1)                 11
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# batch_size = 128
epochs = 1000000

model.compile(loss="mse", optimizer=tf.keras.optimizers.SGD(lr=1e-5, momentum=0.9))
model.fit(xtrain, ytrain, batch_size=None, epochs=epochs, validation_split=0.1, verbose=0)

# %%
model.weights
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(2, 10) dtype=float32, numpy=
#  array([[ 0.5435566 ,  0.00836836, -0.12305832, -0.33323553, -0.4285509 ,
#           0.03700161,  0.13106582, -0.80996275, -0.61742467, -0.7788618 ],
#         [-0.13970502, -0.44889933, -0.4781046 ,  1.087988  ,  0.11998032,
#          -0.49490848, -0.46907085,  0.50496966, -0.4463026 ,  0.38203046]],
#        dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(10,) dtype=float32, numpy=
#  array([ 0.14827916, -0.00239249,  0.        ,  0.05406873, -0.08442777,
#          0.05192628, -0.03757135, -0.04860642,  0.        ,  0.11032874],
#        dtype=float32)>,
#  <tf.Variable 'dense_3/kernel:0' shape=(10, 10) dtype=float32, numpy=
#  array([[ 0.46083075, -0.02304852,  0.0310719 , -0.27338985, -0.12563995,
#          -0.49816614, -0.10256813,  0.4016695 ,  0.20729409, -0.01918279],
#         [-0.45601743, -0.13481972,  0.29137617, -0.44319767,  0.26719165,
# ...

# %%
y
# Out:
# array([0.42730098, 0.40782703, 0.36879473, 0.35578356, 0.33608878,
#        0.31960835, 0.31093433, 0.29935221, 0.29613776, 0.29243023,
#        0.29164794, 0.29557661, 0.30511802, 0.30555988, 0.30603643,
#        0.21909322, 0.24695178, 0.2591969 , 0.28205541, 0.29695393,
#        0.30807715, 0.31634287, 0.31960835, 0.32363906, 0.32573111,
#        0.32712567, 0.32598622, 0.32073106, 0.31766968, 0.31236308,
#        0.30675034, 0.29256636, 0.28144313, 0.26695255, 0.25868667,
#        0.18623399, 0.17756028, 0.17197321, 0.17038318, 0.17184571,
#        0.17944803, 0.18847921, 0.19618368, 0.21228981, 0.22592989,
#        0.24099903, 0.25567657, 0.26756467, 0.27974244, 0.28708975,
#        0.2926683 , 0.30389346, 0.30833247, 0.31537334, 0.34665054,
#        0.35195714, 0.36088596, 0.36879473, 0.39920404, 0.45291454,
#        0.48053513, 0.51023052, 0.63773672, 0.65064565, 0.67438829,
#        0.69906659, 0.72667014, 0.74020817, 0.76922333, 0.77272657,
# ...

# %%
model.save('nn_lonlon10_10_1.h5')
